# %% [markdown]
# <a href="https://colab.research.google.com/github/karthiksuk/MLExamples/blob/main/ML2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Handling categorical Data

# %%
import pandas as pd

df = pd.DataFrame([
                   ['green', 'M', 10.1, 'class2'],
                   ['red', 'L', 13.5, 'class1'],
                   ['blue', 'XL', 15.3, 'class2']
])

df
# Out:
#        0   1     2       3
# 0  green   M  10.1  class2
# 1    red   L  13.5  class1
# 2   blue  XL  15.3  class2

# %% [markdown]
# label the column names using the .columns function and assigning a corresponding list of column names.

# %%
df.columns = ['color', 'size', 'price', 'classlabel']
df
# Out:
#    color size  price classlabel
# 0  green    M   10.1     class2
# 1    red    L   13.5     class1
# 2   blue   XL   15.3     class2

# %% [markdown]
# **Mapping features**

# %%
size_mapping = {'XL': 3,
                'L': 2,
                'M': 1}
      
size_mapping
# Out:
# {'XL': 3, 'L': 2, 'M': 1}

# %%
df['size'] = df['size'].map(size_mapping)
df
# Out:
#    color  size  price classlabel
# 0  green     1   10.1     class2
# 1    red     2   13.5     class1
# 2   blue     3   15.3     class2

# %% [markdown]
# ###Encoding class labels

# %%
import numpy as np

class_mapping = {label: idx for idx, label in 
                 enumerate(np.unique(df['classlabel']))}
class_mapping
# Out:
# {'class1': 0, 'class2': 1}

# %%
df['classlabel'] = df['classlabel'].map(class_mapping)
df
# Out:
#    color  size  price  classlabel
# 0  green     1   10.1           1
# 1    red     2   13.5           0
# 2   blue     3   15.3           1

# %% [markdown]
# reverse the mapping of values back to their original categorical labels.

# %%
inverse_class_mapping = {idx: label for label, idx in class_mapping.items()}
df['classlabel'] = df['classlabel'].map(inverse_class_mapping)

df
# Out:
#    color  size  price classlabel
# 0  green     1   10.1     class2
# 1    red     2   13.5     class1
# 2   blue     3   15.3     class2

# %% [markdown]
# ##Performing one-hot encoding on nominal features

# %%
from sklearn.preprocessing import LabelEncoder

X = df[['color', 'size', 'price']].values
color_le = LabelEncoder()
X[:, 0] = color_le.fit_transform(X[:, 0])
X
# Out:
# array([[1, 1, 10.1],
#        [2, 2, 13.5],
#        [0, 3, 15.3]], dtype=object)
